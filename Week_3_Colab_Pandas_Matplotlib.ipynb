# %% [markdown]
# <a href="https://colab.research.google.com/github/cher-16/maths-python-notebooks/blob/main/Week_3_Colab_Pandas_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Week 3: Data Handling and Visualization (pandas + Matplotlib)
#
# This week you'll learn how to:
# - Use `pandas` to load, view, and analyze tabular data
# - Use `Matplotlib` to plot and visualize that data
# - Practice basic statistics like mean, median, standard deviation

# %%
import pandas as pd

# Create a sample DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Score': [88, 92, 79],
        'Passed': [True, True, False]}
df = pd.DataFrame(data)

# Display the table
print(df)

# Describe basic stats
print(df.describe())

# %% [markdown]
# ## 🌟 Challenge: Data Analysis
#
# 1. Create your own DataFrame with at least 4 students and their scores in 3 subjects.
# 2. Calculate the average score for each student.
# 3. Add a column called `Grade` with "Pass" or "Fail" (passing = average ≥ 60).

# %%
# Your pandas challenge code here
import pandas as pd

# Create a DataFrame
data = {'Name': ['Alice', 'Bette', 'Carmen', 'Dana'],
        'Maths': [90, 60, 70, 80],
        'English': [90, 70, 50, 30],
        'Music': [60, 35, 90, 50]}
df = pd.DataFrame(data)

# Calculate the average for each student
df['Average'] = df[['English', 'Maths', 'Music']].mean(axis=1)
print('Average')

# Add a column called 'Grade'
df['Grade'] = df['Average'].apply(lambda x: 'Pass' if x>=60 else 'Fail')
print(df)
# Out:
# Average
#      Name  Maths  English  Music    Average Grade
# 0   Alice     90       90     60  80.000000  Pass
# 1   Bette     60       70     35  55.000000  Fail
# 2  Carmen     70       50     90  70.000000  Pass
# 3    Dana     80       30     50  53.333333  Fail

# %%
import matplotlib.pyplot as plt

# Sample bar plot
names = ['Alice', 'Bob', 'Charlie']
scores = [88, 92, 79]

plt.bar(names, scores)
plt.title("Scores by Student")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# ## 🌟 Challenge: Plot Your Data
#
# 1. Plot your custom DataFrame (from above) using a bar plot.
# 2. Create a line plot showing the trend of one student’s scores across subjects.

# %%
# Your plot challenge code here
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame
data = {'Name': ['Alice', 'Bette', 'Carmen', 'Dana'],
        'Maths': [90, 60, 70, 80],
        'English': [90, 70, 50, 30],
        'Music': [60, 35, 90, 50]}
df = pd.DataFrame(data)

# Calculate the average for each student
df['Average'] = df[['English', 'Maths', 'Music']].mean(axis=1)
print(df)

# Create a bar plot
# Corrected: Pass the actual data series for x and y
plt.bar(x = df['Name'], height = df['Average'])
plt.title("Average Scores by Student")
plt.xlabel("Names")
plt.ylabel("Average Scores")
plt.show()

# Create a line plot
# Corrected: Pass the actual data series for x and y
plt.plot(df['Name'], df['Average'])
plt.title("Average Scores by Student")
plt.xlabel("Names")
plt.ylabel("Average Score")
plt.show()

# Generate Descriptive Statistics (extra)
df.describe()
print(df.describe())
# Out:
#      Name  Maths  English  Music    Average
# 0   Alice     90       90     60  80.000000
# 1   Bette     60       70     35  55.000000
# 2  Carmen     70       50     90  70.000000
# 3    Dana     80       30     50  53.333333
#            Maths    English      Music    Average
# count   4.000000   4.000000   4.000000   4.000000
# mean   75.000000  60.000000  58.750000  64.583333
# std    12.909944  25.819889  23.228933  12.720281
# min    60.000000  30.000000  35.000000  53.333333
# 25%    67.500000  45.000000  46.250000  54.583333
# 50%    75.000000  60.000000  55.000000  62.500000
# 75%    82.500000  75.000000  67.500000  72.500000
# max    90.000000  90.000000  90.000000  80.000000

# %% [markdown]
# ## 🧪 Quick Quiz
#
# 1. What does `df.describe()` do?
# 2. How can you get the average of a column in pandas?
# 3. What does `plt.bar()` do?

# %% [markdown]
# Your answers here:
# 1. It generates descriptive statistics of a DataFrame. It provides a summary of the central tendency, dispersion, and shape of a dataset's distribution, excluding NaN (Not a Number) values.
# 2. df['Column Name'].mean()
# 3. plot a bar plot
